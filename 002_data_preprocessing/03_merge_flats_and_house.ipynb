# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv(r'../003_cleaned_data/01_flats_cleaned.csv')
houses = pd.read_csv(r'../003_cleaned_data/02_house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0  2 BHK Flat in Sector 95A Gurgaon          flat
# 1   3 BHK Flat in Sector 92 Gurgaon          flat
# 2  2 BHK Flat in Sector 102 Gurgaon          flat
# 3               2 BHK Flat in Sohna          flat
# 4   2 BHK Flat in Sector 85 Gurgaon          flat
#
#                        society  price  price_per_sqft    area  \
# 0                the roselia 2   0.45          6475.0   695.0
# 1  bestech park view sanskruti   1.55          9687.0  1600.0
# 2  shapoorji pallonji joyville   1.10         12022.0   915.0
# 3        signature global park   0.67          5537.0  1210.0
# 4                   godrej air   1.40         10000.0  1400.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Built Up area: 695 (64.57 sq.m.)Carpet area: 5...      2.0       2.0
# 1  Super Built up area 1995(185.34 sq.m.)Carpet a...      3.0       3.0
# ...

# %%
import os

# Create the folder if it doesn't exist
os.makedirs('../003_cleaned_data', exist_ok=True)

# Save the file (noting the .. to go up one level from your current notebook folder)
df.to_csv('../003_cleaned_data/03_gurgaon_properties.csv', index=False)
